# %%
#import dependencies & setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path
# %matplotlib inline

# %%
# Load CSV files
may_2023_data_to_load = Path("Resources/JC-202305-citibike-tripdata.csv")
june_2023_data_to_load = Path("Resources/JC-202306-citibike-tripdata.csv")
july_2023_data_to_load = Path("Resources/JC-202307-citibike-tripdata.csv")

# read CSV
data_may_2023 = pd.read_csv(may_2023_data_to_load)
data_june_2023 = pd.read_csv(june_2023_data_to_load)
data_july_2023 = pd.read_csv(july_2023_data_to_load)


# convert to pandas df
citibike_may_2023_df = pd.DataFrame(data_may_2023)

# %%
# Visualize the dataframes

# MARCH DATA
citibike_march_2020_df.head()

# DF info
# citibike_march_2020_df.info()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1589  2020-03-01 00:00:03.6400  2020-03-01 00:26:32.9860
# 1           389  2020-03-01 00:00:16.7560  2020-03-01 00:06:46.0620
# 2           614  2020-03-01 00:00:20.0580  2020-03-01 00:10:34.2200
# 3           597  2020-03-01 00:00:24.3510  2020-03-01 00:10:22.3390
# 4          1920  2020-03-01 00:00:26.1120  2020-03-01 00:32:26.2680
#
#    start station id        start station name  start station latitude  \
# 0               224     Spruce St & Nassau St               40.711464
# 1               293     Lafayette St & E 8 St               40.730207
# 2               379           W 31 St & 7 Ave               40.749156
# 3              3739  Perry St & Greenwich Ave               40.735918
# 4               236       St Marks Pl & 2 Ave               40.728419
#
#    start station longitude  end station id             end station name  \
# ...

# %%
# APRIL DATA
citibike_april_2020_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           534  2020-04-01 00:00:15.2800  2020-04-01 00:09:09.8730
# 1           529  2020-04-01 00:02:28.9430  2020-04-01 00:11:18.3410
# 2          1488  2020-04-01 00:02:56.0900  2020-04-01 00:27:44.2530
# 3           341  2020-04-01 00:03:25.1410  2020-04-01 00:09:06.3190
# 4          2206  2020-04-01 00:05:35.2790  2020-04-01 00:42:21.9080
#
#    start station id           start station name  start station latitude  \
# 0              3656            E 2 St & Avenue A               40.723077
# 1              3163  Central Park West & W 68 St               40.773407
# 2              3164       Columbus Ave & W 72 St               40.777057
# 3              3827         Halsey St & Broadway               40.685650
# 4              3890          Grove St & Broadway               40.690470
#
#    start station longitude  end station id           end station name  \
# ...

# %%
# MAY DATA
citibike_may_2020_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           336  2020-05-01 00:01:06.3380  2020-05-01 00:06:42.9560
# 1           853  2020-05-01 00:01:08.1950  2020-05-01 00:15:21.2150
# 2            78  2020-05-01 00:01:08.5260  2020-05-01 00:02:27.0490
# 3          1185  2020-05-01 00:02:22.4380  2020-05-01 00:22:08.1220
# 4           272  2020-05-01 00:02:32.8280  2020-05-01 00:07:05.0880
#
#    start station id                  start station name  \
# 0              2017                     E 43 St & 2 Ave
# 1              3376                     E 65 St & 2 Ave
# 2               396          Lefferts Pl & Franklin Ave
# 3              3630  Frederick Douglass Blvd & W 115 St
# 4              3776          Central Ave & Starr Street
#
#    start station latitude  start station longitude  end station id  \
# 0               40.750224               -73.971214             465
# 1               40.764719               -73.962221             478
# ...

# %% [markdown]
# ## Exploratory Analysis
# Find two unexpected phenomena, and design 2-5 visualizations for each phenomena (4-10 total).

# %%
# 1. How many trips have been recorded during the chosen period(s)?

# March 2020
march_trips = citibike_march_2020_df['starttime'].nunique()
print(f'There were a total of {march_trips} Citi Bike trips recorded during March 2020.')

# April 2020
april_trips = citibike_april_2020_df['starttime'].nunique()
print(f'There were a total of {april_trips} Citi Bike trips recorded during April 2020.')

# May 2020
may_trips = citibike_may_2020_df['starttime'].nunique()
print(f'There were a total of {may_trips} Citi Bike trips recorded during May 2020.')
# Out:
# There were a total of 1068008 Citi Bike trips recorded during March 2020.
# There were a total of 682529 Citi Bike trips recorded during April 2020.
# There were a total of 1486972 Citi Bike trips recorded during May 2020.
